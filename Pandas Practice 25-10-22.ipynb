# %%
import pandas as pd

# %%
#Series
a=pd.Series([1,2,3,4,5])

# %%
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
b=pd.Series([4,6,7,4,9])

# %%
b
# Out:
# 0    4
# 1    6
# 2    7
# 3    4
# 4    9
# dtype: int64

# %%
# Indexing
a=pd.Series([1,2,3,5,6],index=[1,2,3,4,5])

# %%
a
# Out:
# 1    1
# 2    2
# 3    3
# 4    5
# 5    6
# dtype: int64

# %%
b=pd.Series([2,3,4,5,7],index=[1,2,3,4,4])

# %%
b
# Out:
# 1    2
# 2    3
# 3    4
# 4    5
# 4    7
# dtype: int64

# %%
# Dictonar
dict1={'id':[1,2,3,4,5],'name':['Swapnil','Sarthak','Sarang','Vihan','Sanket']}

# %%
dict1
# Out:
# {'id': [1, 2, 3, 4, 5],
#  'name': ['Swapnil', 'Sarthak', 'Sarang', 'Vihan', 'Sanket']}

# %%
a=pd.Series(dict1)

# %%
a
# Out:
# id                                [1, 2, 3, 4, 5]
# name    [Swapnil, Sarthak, Sarang, Vihan, Sanket]
# dtype: object

# %%
dict2={'id':[1,2,3],'name':['A','B','C']}

# %%
a=pd.Series(dict2)

# %%
a
# Out:
# id      [1, 2, 3]
# name    [A, B, C]
# dtype: object

# %%
# Indexing & slicing

a[1]
# Out:
# ['A', 'B', 'C']

# %%
a[0]
# Out:
# [1, 2, 3]

# %%
a[0:2]
# Out:
# id      [1, 2, 3]
# name    [A, B, C]
# dtype: object

# %%
a[1][1]
# Out:
# 'B'

# %%
a[1][-3:-1]
# Out:
# ['A', 'B']

# %%
a[1][:-1]
# Out:
# ['A', 'B']

# %%
a[0][0:2],a[1][0:2]
# Out:
# ([1, 2], ['A', 'B'])

# %%
L2=[[1,'Sarang'],[2,'Sarthak'],[3,'Sanket']]

# %%
# Dataframe

a=pd.DataFrame(L2)

# %%
a
# Out:
#    0        1
# 0  1   Sarang
# 1  2  Sarthak
# 2  3   Sanket

# %%
a=pd.DataFrame(L2,index=[1,2,3],columns=['id','name'])

# %%
a
# Out:
#    id     name
# 1   1   Sarang
# 2   2  Sarthak
# 3   3   Sanket

# %%
import numpy as np

# %%
a=pd.DataFrame(np.random.randint(0,20,size=(4,5)))

# %%
a
# Out:
#     0   1  2   3   4
# 0   6  16  9  19  13
# 1   8  12  5   5  11
# 2  12   3  0   6  16
# 3   1  18  2   0   2

# %%
a=pd.DataFrame(np.random.randint(0,20,size=(4,5)),columns=['a','b','c','d','e'])

# %%
a
# Out:
#     a   b   c   d   e
# 0   7   3  16   1   8
# 1  15  12   4  17   7
# 2  19  19   1   0   5
# 3  13   4  13   0  13

# %%
# loc - Means location

a.loc[0:2,'a']
# Out:
# 0     7
# 1    15
# 2    19
# Name: a, dtype: int32

# %%
a.loc[0:3,'a']
# Out:
# 0     7
# 1    15
# 2    19
# 3    13
# Name: a, dtype: int32

# %%
a.loc[1:2,['a','b','c','d','e']]
# Out:
#     a   b  c   d  e
# 1  15  12  4  17  7
# 2  19  19  1   0  5

# %%
a.loc[0:3,['a','c']]
# Out:
#     a   c
# 0   7  16
# 1  15   4
# 2  19   1
# 3  13  13

# %%
# iloc - Means index location

a.iloc[:,0]
# Out:
# 0     7
# 1    15
# 2    19
# 3    13
# Name: a, dtype: int32

# %%
a.iloc[0:2,0:1]
# Out:
#     a
# 0   7
# 1  15

# %%
a.iloc[0:2,0:2]
# Out:
#     a   b
# 0   7   3
# 1  15  12

# %%
a
# Out:
#     a   b   c   d   e
# 0   7   3  16   1   8
# 1  15  12   4  17   7
# 2  19  19   1   0   5
# 3  13   4  13   0  13

# %%
print(a.iloc[0:2,0:2])

print(a.iloc[2:,2:])
# Out:
#     a   b
# 0   7   3
# 1  15  12
#     c  d   e
# 2   1  0   5
# 3  13  0  13

# %%
dict1={'id':[1,2,3,4,5],'name':['Swapnil','Sarthak','Sarang','Vihan','Sanket']}

# %%
a=pd.DataFrame(dict1)

# %%
a
# Out:
#    id     name
# 0   1  Swapnil
# 1   2  Sarthak
# 2   3   Sarang
# 3   4    Vihan
# 4   5   Sanket

# %%
a.set_index('id')
# Out:
#        name
# id
# 1   Swapnil
# 2   Sarthak
# 3    Sarang
# 4     Vihan
# 5    Sanket

# %%
a.rename(columns={'name':'st'})
# Out:
#    id       st
# 0   1  Swapnil
# 1   2  Sarthak
# 2   3   Sarang
# 3   4    Vihan
# 4   5   Sanket

# %%
a
# Out:
#    id     name
# 0   1  Swapnil
# 1   2  Sarthak
# 2   3   Sarang
# 3   4    Vihan
# 4   5   Sanket

# %%
a.rename(columns={'name':'emp'})
# Out:
#    id      emp
# 0   1  Swapnil
# 1   2  Sarthak
# 2   3   Sarang
# 3   4    Vihan
# 4   5   Sanket

# %%
a.rename(columns={'name':'emp'},inplace=True)

# %%
a
# Out:
#    id      emp
# 0   1  Swapnil
# 1   2  Sarthak
# 2   3   Sarang
# 3   4    Vihan
# 4   5   Sanket

# %%
file=pd.read_csv('winedata.csv')

# %%
file
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
file=pd.read_csv('empData.csv')

# %%
a=pd.DataFrame(file)

# %%
a
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
a.head()
# Out:
#    SNo   Name   Age      City  Country   Salary
# 0    1    Tom  28.0   Toronto   Canada  20000.0
# 1    2    Lee  31.0   Edmonto   Canada   3900.0
# 2    3   Dave  34.0   Toronto   Canada   8000.0
# 3    4   Anik  26.0  HongKong     Asia  66672.0
# 4    5  kamal  30.0       NaN  America      NaN

# %%
a.head(2)
# Out:
#    SNo Name   Age     City Country   Salary
# 0    1  Tom  28.0  Toronto  Canada  20000.0
# 1    2  Lee  31.0  Edmonto  Canada   3900.0

# %%
a.head(7)
# Out:
#    SNo    Name   Age      City  Country   Salary
# 0    1     Tom  28.0   Toronto   Canada  20000.0
# 1    2     Lee  31.0   Edmonto   Canada   3900.0
# 2    3    Dave  34.0   Toronto   Canada   8000.0
# 3    4    Anik  26.0  HongKong     Asia  66672.0
# 4    5   kamal  30.0       NaN  America      NaN
# 5    6    Geet   NaN  HongKong     Asia  30007.0
# 6    7  Steven  43.0   BayArea  America   8300.0

# %%
a.head(3)
# Out:
#    SNo  Name   Age     City Country   Salary
# 0    1   Tom  28.0  Toronto  Canada  20000.0
# 1    2   Lee  31.0  Edmonto  Canada   3900.0
# 2    3  Dave  34.0  Toronto  Canada   8000.0

# %%
a.tail()
# Out:
#     SNo    Name   Age     City Country   Salary
# 17   19     Lee  31.0  Edmonto  Canada      NaN
# 18   20  Andrew  34.0    Congo  Africa  34432.0
# 19   21   soham  32.0   Angola  Africa  34534.0
# 20   22    Grig  26.0  Finland  Europe  33451.0
# 21   23   Kiara  27.0   London  Europe      NaN

# %%
a.tail(3)
# Out:
#     SNo   Name   Age     City Country   Salary
# 19   21  soham  32.0   Angola  Africa  34534.0
# 20   22   Grig  26.0  Finland  Europe  33451.0
# 21   23  Kiara  27.0   London  Europe      NaN

# %%
a.set_index('SNo')
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
file=pd.read_csv('empData.csv',header=0,names=['SNO','NAME','AGE','CITY','COUNTRY','SALARY'])

# %%
a = pd.DataFrame(file)

# %%
a.set_index('SNO')
# Out:
#        NAME   AGE       CITY  COUNTRY   SALARY
# SNO
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
a.head()
# Out:
#    SNO   NAME   AGE      CITY  COUNTRY   SALARY
# 0    1    Tom  28.0   Toronto   Canada  20000.0
# 1    2    Lee  31.0   Edmonto   Canada   3900.0
# 2    3   Dave  34.0   Toronto   Canada   8000.0
# 3    4   Anik  26.0  HongKong     Asia  66672.0
# 4    5  kamal  30.0       NaN  America      NaN

# %%
a.columns
# Out:
# Index(['SNO', 'NAME', 'AGE', 'CITY', 'COUNTRY', 'SALARY'], dtype='object')

# %%
a
# Out:
#     SNO    NAME   AGE       CITY  COUNTRY   SALARY
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
a.count()
# Out:
# SNO        22
# NAME       22
# AGE        19
# CITY       19
# COUNTRY    22
# SALARY     19
# dtype: int64

# %%
a.describe()
# Out:
#              SNO        AGE        SALARY
# count  22.000000  19.000000     19.000000
# mean   12.090909  32.421053  33739.947368
# std     6.927578   7.174924  23151.188084
# min     1.000000  22.000000   3900.000000
# 25%     6.250000  27.000000   8888.000000
# 50%    12.500000  31.000000  33451.000000
# 75%    17.750000  36.000000  54666.000000
# max    23.000000  50.000000  67666.000000

# %%
a.describe(include='all')
# Out:
#               SNO NAME        AGE      CITY  COUNTRY        SALARY
# count   22.000000   22  19.000000        19       22     19.000000
# unique        NaN   14        NaN        10        5           NaN
# top           NaN  Lee        NaN  HongKong  America           NaN
# freq          NaN    2        NaN         4        8           NaN
# mean    12.090909  NaN  32.421053       NaN      NaN  33739.947368
# std      6.927578  NaN   7.174924       NaN      NaN  23151.188084
# min      1.000000  NaN  22.000000       NaN      NaN   3900.000000
# 25%      6.250000  NaN  27.000000       NaN      NaN   8888.000000
# 50%     12.500000  NaN  31.000000       NaN      NaN  33451.000000
# 75%     17.750000  NaN  36.000000       NaN      NaN  54666.000000
# max     23.000000  NaN  50.000000       NaN      NaN  67666.000000

# %%
a['NAME'].describe()
# Out:
# count      22
# unique     14
# top       Lee
# freq        2
# Name: NAME, dtype: object

# %%
a['NAME'].unique()
# Out:
# array(['Tom', 'Lee', 'Dave', 'Anik', 'kamal', 'Geet', 'Steven', 'Ram',
#        'hari', 'yami', 'Andrew', 'soham', 'Grig', 'Kiara'], dtype=object)

# %%
a['NAME'].nunique()
# Out:
# 14

# %%
a['NAME'].count()
# Out:
# 22

# %%
a.count()
# Out:
# SNO        22
# NAME       22
# AGE        19
# CITY       19
# COUNTRY    22
# SALARY     19
# dtype: int64

# %%
a['SALARY'].max()
# Out:
# 67666.0

# %%
a['SALARY'].min()
# Out:
# 3900.0

# %%
a.head()
# Out:
#    SNO   NAME   AGE      CITY  COUNTRY   SALARY
# 0    1    Tom  28.0   Toronto   Canada  20000.0
# 1    2    Lee  31.0   Edmonto   Canada   3900.0
# 2    3   Dave  34.0   Toronto   Canada   8000.0
# 3    4   Anik  26.0  HongKong     Asia  66672.0
# 4    5  kamal  30.0       NaN  America      NaN

# %%
a.columns
# Out:
# Index(['SNO', 'NAME', 'AGE', 'CITY', 'COUNTRY', 'SALARY'], dtype='object')

# %%
a.count()
# Out:
# SNO        22
# NAME       22
# AGE        19
# CITY       19
# COUNTRY    22
# SALARY     19
# dtype: int64

# %%
a.describe()
# Out:
#              SNO        AGE        SALARY
# count  22.000000  19.000000     19.000000
# mean   12.090909  32.421053  33739.947368
# std     6.927578   7.174924  23151.188084
# min     1.000000  22.000000   3900.000000
# 25%     6.250000  27.000000   8888.000000
# 50%    12.500000  31.000000  33451.000000
# 75%    17.750000  36.000000  54666.000000
# max    23.000000  50.000000  67666.000000

# %%
a.describe(include='all')
# Out:
#               SNO NAME        AGE      CITY  COUNTRY        SALARY
# count   22.000000   22  19.000000        19       22     19.000000
# unique        NaN   14        NaN        10        5           NaN
# top           NaN  Lee        NaN  HongKong  America           NaN
# freq          NaN    2        NaN         4        8           NaN
# mean    12.090909  NaN  32.421053       NaN      NaN  33739.947368
# std      6.927578  NaN   7.174924       NaN      NaN  23151.188084
# min      1.000000  NaN  22.000000       NaN      NaN   3900.000000
# 25%      6.250000  NaN  27.000000       NaN      NaN   8888.000000
# 50%     12.500000  NaN  31.000000       NaN      NaN  33451.000000
# 75%     17.750000  NaN  36.000000       NaN      NaN  54666.000000
# max     23.000000  NaN  50.000000       NaN      NaN  67666.000000

# %%
a['NAME'].describe()
# Out:
# count      22
# unique     14
# top       Lee
# freq        2
# Name: NAME, dtype: object

# %%
a['SALARY'].describe()
# Out:
# count       19.000000
# mean     33739.947368
# std      23151.188084
# min       3900.000000
# 25%       8888.000000
# 50%      33451.000000
# 75%      54666.000000
# max      67666.000000
# Name: SALARY, dtype: float64

# %%
a['NAME'].count()
# Out:
# 22

# %%
a['NAME'].unique()
# Out:
# array(['Tom', 'Lee', 'Dave', 'Anik', 'kamal', 'Geet', 'Steven', 'Ram',
#        'hari', 'yami', 'Andrew', 'soham', 'Grig', 'Kiara'], dtype=object)

# %%
a['NAME'].nunique()
# Out:
# 14

# %%
a['SALARY'].max()
# Out:
# 67666.0

# %%
a['SALARY'].min()
# Out:
# 3900.0

# %%
a['SALARY'].sum()
# Out:
# 641059.0

# %%
a
# Out:
#     SNO    NAME   AGE       CITY  COUNTRY   SALARY
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
a2= a.drop(['CITY'],axis=1)

# %%
a2
# Out:
#     SNO    NAME   AGE  COUNTRY   SALARY
# 0     1     Tom  28.0   Canada  20000.0
# 1     2     Lee  31.0   Canada   3900.0
# 2     3    Dave  34.0   Canada   8000.0
# 3     4    Anik  26.0     Asia  66672.0
# 4     5   kamal  30.0  America      NaN
# 5     6    Geet   NaN     Asia  30007.0
# 6     7  Steven  43.0  America   8300.0
# 7     8     Ram  38.0     Asia  54666.0
# 8     9    hari  50.0  America  67666.0
# 9    11    yami   NaN  America   8888.0
# 10   12    Anik  26.0     Asia  66672.0
# 11   13   kamal  30.0  America  34344.0
# 12   14    Geet  22.0     Asia  30007.0
# 13   15  Steven  43.0  America   8300.0
# 14   16     Ram  38.0     Asia  54666.0
# 15   17    hari   NaN  America  67666.0
# 16   18    yami  27.0  America   8888.0
# 17   19     Lee  31.0   Canada      NaN
# 18   20  Andrew  34.0   Africa  34432.0
# 19   21   soham  32.0   Africa  34534.0
# 20   22    Grig  26.0   Europe  33451.0
# 21   23   Kiara  27.0   Europe      NaN

# %%
a
# Out:
#     SNO    NAME   AGE       CITY  COUNTRY   SALARY
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
a.drop(['CITY','COUNTRY'],axis=1,inplace=True)

# %%
a
# Out:
#     SNO    NAME   AGE   SALARY
# 0     1     Tom  28.0  20000.0
# 1     2     Lee  31.0   3900.0
# 2     3    Dave  34.0   8000.0
# 3     4    Anik  26.0  66672.0
# 4     5   kamal  30.0      NaN
# 5     6    Geet   NaN  30007.0
# 6     7  Steven  43.0   8300.0
# 7     8     Ram  38.0  54666.0
# 8     9    hari  50.0  67666.0
# 9    11    yami   NaN   8888.0
# 10   12    Anik  26.0  66672.0
# 11   13   kamal  30.0  34344.0
# 12   14    Geet  22.0  30007.0
# 13   15  Steven  43.0   8300.0
# 14   16     Ram  38.0  54666.0
# 15   17    hari   NaN  67666.0
# 16   18    yami  27.0   8888.0
# 17   19     Lee  31.0      NaN
# 18   20  Andrew  34.0  34432.0
# 19   21   soham  32.0  34534.0
# 20   22    Grig  26.0  33451.0
# 21   23   Kiara  27.0      NaN

# %%
a
# Out:
#     SNO    NAME   AGE   SALARY
# 0     1     Tom  28.0  20000.0
# 1     2     Lee  31.0   3900.0
# 2     3    Dave  34.0   8000.0
# 3     4    Anik  26.0  66672.0
# 4     5   kamal  30.0      NaN
# 5     6    Geet   NaN  30007.0
# 6     7  Steven  43.0   8300.0
# 7     8     Ram  38.0  54666.0
# 8     9    hari  50.0  67666.0
# 9    11    yami   NaN   8888.0
# 10   12    Anik  26.0  66672.0
# 11   13   kamal  30.0  34344.0
# 12   14    Geet  22.0  30007.0
# 13   15  Steven  43.0   8300.0
# 14   16     Ram  38.0  54666.0
# 15   17    hari   NaN  67666.0
# 16   18    yami  27.0   8888.0
# 17   19     Lee  31.0      NaN
# 18   20  Andrew  34.0  34432.0
# 19   21   soham  32.0  34534.0
# 20   22    Grig  26.0  33451.0
# 21   23   Kiara  27.0      NaN

# %%
a.set_index('SNO')
# Out:
#        NAME   AGE   SALARY
# SNO
# 1       Tom  28.0  20000.0
# 2       Lee  31.0   3900.0
# 3      Dave  34.0   8000.0
# 4      Anik  26.0  66672.0
# 5     kamal  30.0      NaN
# 6      Geet   NaN  30007.0
# 7    Steven  43.0   8300.0
# 8       Ram  38.0  54666.0
# 9      hari  50.0  67666.0
# 11     yami   NaN   8888.0
# 12     Anik  26.0  66672.0
# 13    kamal  30.0  34344.0
# 14     Geet  22.0  30007.0
# 15   Steven  43.0   8300.0
# 16      Ram  38.0  54666.0
# 17     hari   NaN  67666.0
# 18     yami  27.0   8888.0
# 19      Lee  31.0      NaN
# 20   Andrew  34.0  34432.0
# 21    soham  32.0  34534.0
# 22     Grig  26.0  33451.0
# 23    Kiara  27.0      NaN

# %%
a2=a.drop([1,2],axis=0)

# %%
a2
# Out:
#     SNO    NAME   AGE   SALARY
# 0     1     Tom  28.0  20000.0
# 3     4    Anik  26.0  66672.0
# 4     5   kamal  30.0      NaN
# 5     6    Geet   NaN  30007.0
# 6     7  Steven  43.0   8300.0
# 7     8     Ram  38.0  54666.0
# 8     9    hari  50.0  67666.0
# 9    11    yami   NaN   8888.0
# 10   12    Anik  26.0  66672.0
# 11   13   kamal  30.0  34344.0
# 12   14    Geet  22.0  30007.0
# 13   15  Steven  43.0   8300.0
# 14   16     Ram  38.0  54666.0
# 15   17    hari   NaN  67666.0
# 16   18    yami  27.0   8888.0
# 17   19     Lee  31.0      NaN
# 18   20  Andrew  34.0  34432.0
# 19   21   soham  32.0  34534.0
# 20   22    Grig  26.0  33451.0
# 21   23   Kiara  27.0      NaN

# %%
a.head()
# Out:
#    SNO   NAME   AGE   SALARY
# 0    1    Tom  28.0  20000.0
# 1    2    Lee  31.0   3900.0
# 2    3   Dave  34.0   8000.0
# 3    4   Anik  26.0  66672.0
# 4    5  kamal  30.0      NaN

# %%
a.set_index('SNO',inplace=True)

# %%
a.head()
# Out:
#       NAME   AGE   SALARY
# SNO
# 1      Tom  28.0  20000.0
# 2      Lee  31.0   3900.0
# 3     Dave  34.0   8000.0
# 4     Anik  26.0  66672.0
# 5    kamal  30.0      NaN

# %%
file=pd.read_csv('MATHS1.csv')

# %%
file.head()
# Out:
#    Rollno                     Name Oral Written         DOB
# 0       1       AARVI VIKRAM PATIL    A      A+   12/7/2012
# 1       2         AVANI AMOL KADAM    A       A  17/01/2012
# 2       3  AYANA AZHARUDDIN SHAIKH    A      B+  31/12/2012
# 3       4     DIKSHA NAGESH HAJARE   B+       B  13/08/2012
# 4       5    DISHA SHRIKANT TAVARE   B+      A+  22/05/2012

# %%
file=pd.read_csv('MATHS1.csv',parse_dates=['DOB'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '17/01/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '31/12/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '13/08/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '22/05/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# ...

# %%
file.head()
# Out:
#    Rollno                     Name Oral Written        DOB
# 0       1       AARVI VIKRAM PATIL    A      A+ 2012-12-07
# 1       2         AVANI AMOL KADAM    A       A 2012-01-17
# 2       3  AYANA AZHARUDDIN SHAIKH    A      B+ 2012-12-31
# 3       4     DIKSHA NAGESH HAJARE   B+       B 2012-08-13
# 4       5    DISHA SHRIKANT TAVARE   B+      A+ 2012-05-22

# %%
type(file['DOB'][1])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
daterange=pd.date_range(start='25/10/22',end='26/10/23',freq='M')

# %%
daterange
# Out:
# DatetimeIndex(['2022-10-31', '2022-11-30', '2022-12-31', '2023-01-31',
#                '2023-02-28', '2023-03-31', '2023-04-30', '2023-05-31',
#                '2023-06-30', '2023-07-31', '2023-08-31', '2023-09-30'],
#               dtype='datetime64[ns]', freq='M')

# %%
daterange=pd.date_range(start='10/25/2022',end='11/05/2022',freq='D')

# %%
daterange
# Out:
# DatetimeIndex(['2022-10-25', '2022-10-26', '2022-10-27', '2022-10-28',
#                '2022-10-29', '2022-10-30', '2022-10-31', '2022-11-01',
#                '2022-11-02', '2022-11-03', '2022-11-04', '2022-11-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
daterange=pd.date_range(start='25/10/22',end='26/10/25',freq='Y')

# %%
daterange
# Out:
# DatetimeIndex(['2022-12-31', '2023-12-31', '2024-12-31'], dtype='datetime64[ns]', freq='A-DEC')

# %%
import datetime

# %%
dt=datetime.datetime.now()

# %%
dt
# Out:
# datetime.datetime(2022, 10, 25, 19, 16, 8, 822509)

# %%
dt=datetime.datetime.now()

# %%
dt
# Out:
# datetime.datetime(2022, 10, 25, 19, 17, 13, 427784)

# %%
a = pd.DataFrame(file)

# %%
a
# Out:
#     Rollno                        Name Oral Written        DOB
# 0        1          AARVI VIKRAM PATIL    A      A+ 2012-12-07
# 1        2            AVANI AMOL KADAM    A       A 2012-01-17
# 2        3     AYANA AZHARUDDIN SHAIKH    A      B+ 2012-12-31
# 3        4        DIKSHA NAGESH HAJARE   B+       B 2012-08-13
# 4        5       DISHA SHRIKANT TAVARE   B+      A+ 2012-05-22
# 5        6         HERUMBI ROHIT BAJJA    A       B 2012-09-07
# 6        7          IRA SHARAD KATWATE    A       A 2012-12-22
# 7        8  KAAVYA DATTAPRASAD BIRADAR    A       B 2012-08-13
# 8        9         KARTIKI ROHIT KADAM    A       A 2012-05-22
# 9       10       KASHVI SURESH JAYBHAY   C+     ABS 2012-09-08
# 10      11           MYRA AFJAL PATHAN    B      B+ 2012-12-22
# 11      12         NIRVI RAKESH SHINDE   B+       A 2012-08-13
# 12      13         RIDDHI SACHIN DHAGE    A      B+ 2012-05-22
# 13      14         SAKSHI ASHISH PATIL    A       A 2012-09-09
# ...

# %%
a.columns
# Out:
# Index(['Rollno', 'Name', 'Oral', 'Written', 'DOB'], dtype='object')

# %%
import datetime as dt

# %%
a['day']=a['DOB'].dt.day

# %%
a
# Out:
#     Rollno                        Name Oral Written        DOB  day
# 0        1          AARVI VIKRAM PATIL    A      A+ 2012-12-07    7
# 1        2            AVANI AMOL KADAM    A       A 2012-01-17   17
# 2        3     AYANA AZHARUDDIN SHAIKH    A      B+ 2012-12-31   31
# 3        4        DIKSHA NAGESH HAJARE   B+       B 2012-08-13   13
# 4        5       DISHA SHRIKANT TAVARE   B+      A+ 2012-05-22   22
# 5        6         HERUMBI ROHIT BAJJA    A       B 2012-09-07    7
# 6        7          IRA SHARAD KATWATE    A       A 2012-12-22   22
# 7        8  KAAVYA DATTAPRASAD BIRADAR    A       B 2012-08-13   13
# 8        9         KARTIKI ROHIT KADAM    A       A 2012-05-22   22
# 9       10       KASHVI SURESH JAYBHAY   C+     ABS 2012-09-08    8
# 10      11           MYRA AFJAL PATHAN    B      B+ 2012-12-22   22
# 11      12         NIRVI RAKESH SHINDE   B+       A 2012-08-13   13
# 12      13         RIDDHI SACHIN DHAGE    A      B+ 2012-05-22   22
# ...

# %%
a.head()
# Out:
#    Rollno                     Name Oral Written        DOB  day
# 0       1       AARVI VIKRAM PATIL    A      A+ 2012-12-07    7
# 1       2         AVANI AMOL KADAM    A       A 2012-01-17   17
# 2       3  AYANA AZHARUDDIN SHAIKH    A      B+ 2012-12-31   31
# 3       4     DIKSHA NAGESH HAJARE   B+       B 2012-08-13   13
# 4       5    DISHA SHRIKANT TAVARE   B+      A+ 2012-05-22   22

# %%
a['month']=a['DOB'].dt.month

# %%
a
# Out:
#     Rollno                        Name Oral Written        DOB  day  month
# 0        1          AARVI VIKRAM PATIL    A      A+ 2012-12-07    7     12
# 1        2            AVANI AMOL KADAM    A       A 2012-01-17   17      1
# 2        3     AYANA AZHARUDDIN SHAIKH    A      B+ 2012-12-31   31     12
# 3        4        DIKSHA NAGESH HAJARE   B+       B 2012-08-13   13      8
# 4        5       DISHA SHRIKANT TAVARE   B+      A+ 2012-05-22   22      5
# 5        6         HERUMBI ROHIT BAJJA    A       B 2012-09-07    7      9
# 6        7          IRA SHARAD KATWATE    A       A 2012-12-22   22     12
# 7        8  KAAVYA DATTAPRASAD BIRADAR    A       B 2012-08-13   13      8
# 8        9         KARTIKI ROHIT KADAM    A       A 2012-05-22   22      5
# 9       10       KASHVI SURESH JAYBHAY   C+     ABS 2012-09-08    8      9
# 10      11           MYRA AFJAL PATHAN    B      B+ 2012-12-22   22     12
# ...

# %% [markdown]
# # Pandas SQL

# %%
a[['Name']]
# Out:
#                           Name
# 0           AARVI VIKRAM PATIL
# 1             AVANI AMOL KADAM
# 2      AYANA AZHARUDDIN SHAIKH
# 3         DIKSHA NAGESH HAJARE
# 4        DISHA SHRIKANT TAVARE
# 5          HERUMBI ROHIT BAJJA
# 6           IRA SHARAD KATWATE
# 7   KAAVYA DATTAPRASAD BIRADAR
# 8          KARTIKI ROHIT KADAM
# 9        KASHVI SURESH JAYBHAY
# 10           MYRA AFJAL PATHAN
# 11         NIRVI RAKESH SHINDE
# 12         RIDDHI SACHIN DHAGE
# 13         SAKSHI ASHISH PATIL
# 14        SEJAL SANKET SHITOLE
# 15          SWARA ASHISH PATIL
# 16         SWARALI SAGAR SHETE
# 17       ANISH SANKET SALUNKHE
# 18       RAJVEER YOGESH TAPARE
# 19        RIYANSH SAGAR THORAT
# 20       RUDRA RAJENDRA DALAVI
# 21   RUDRA SHIVSHANKAR RAJBHAR
# 22       SHIVAM VAIBHAV KAMBLE
# 23      SHIVANSH NIKESH BERADE
# 24      SHIVANSH SACHIN SHELAR
# 25        SHIVANSH SURAJ YADAV
# 26    SWARUP SWAPNIL NIMBALKAR
# 27        SWARUP TUSHAR PILANE
# 28    SWAYAM SWAPNIL NIMBALKAR
# ...

# %%
a[['Name','Oral']]
# Out:
#                           Name Oral
# 0           AARVI VIKRAM PATIL    A
# 1             AVANI AMOL KADAM    A
# 2      AYANA AZHARUDDIN SHAIKH    A
# 3         DIKSHA NAGESH HAJARE   B+
# 4        DISHA SHRIKANT TAVARE   B+
# 5          HERUMBI ROHIT BAJJA    A
# 6           IRA SHARAD KATWATE    A
# 7   KAAVYA DATTAPRASAD BIRADAR    A
# 8          KARTIKI ROHIT KADAM    A
# 9        KASHVI SURESH JAYBHAY   C+
# 10           MYRA AFJAL PATHAN    B
# 11         NIRVI RAKESH SHINDE   B+
# 12         RIDDHI SACHIN DHAGE    A
# 13         SAKSHI ASHISH PATIL    A
# 14        SEJAL SANKET SHITOLE    A
# 15          SWARA ASHISH PATIL    A
# 16         SWARALI SAGAR SHETE    B
# 17       ANISH SANKET SALUNKHE    A
# 18       RAJVEER YOGESH TAPARE    A
# 19        RIYANSH SAGAR THORAT    A
# 20       RUDRA RAJENDRA DALAVI    A
# 21   RUDRA SHIVSHANKAR RAJBHAR    A
# 22       SHIVAM VAIBHAV KAMBLE    A
# 23      SHIVANSH NIKESH BERADE   B+
# 24      SHIVANSH SACHIN SHELAR  ABS
# ...

# %%
a[a['Oral']=='A']
# Out:
#     Rollno                        Name Oral Written        DOB  day  month
# 0        1          AARVI VIKRAM PATIL    A      A+ 2012-12-07    7     12
# 1        2            AVANI AMOL KADAM    A       A 2012-01-17   17      1
# 2        3     AYANA AZHARUDDIN SHAIKH    A      B+ 2012-12-31   31     12
# 5        6         HERUMBI ROHIT BAJJA    A       B 2012-09-07    7      9
# 6        7          IRA SHARAD KATWATE    A       A 2012-12-22   22     12
# 7        8  KAAVYA DATTAPRASAD BIRADAR    A       B 2012-08-13   13      8
# 8        9         KARTIKI ROHIT KADAM    A       A 2012-05-22   22      5
# 12      13         RIDDHI SACHIN DHAGE    A      B+ 2012-05-22   22      5
# 13      14         SAKSHI ASHISH PATIL    A       A 2012-09-09    9      9
# 14      15        SEJAL SANKET SHITOLE    A      A+ 2012-12-22   22     12
# 15      16          SWARA ASHISH PATIL    A      B+ 2012-08-13   13      8
# ...

# %%
a[a['Oral']=='A'].head()
# Out:
#    Rollno                     Name Oral Written        DOB  day  month
# 0       1       AARVI VIKRAM PATIL    A      A+ 2012-12-07    7     12
# 1       2         AVANI AMOL KADAM    A       A 2012-01-17   17      1
# 2       3  AYANA AZHARUDDIN SHAIKH    A      B+ 2012-12-31   31     12
# 5       6      HERUMBI ROHIT BAJJA    A       B 2012-09-07    7      9
# 6       7       IRA SHARAD KATWATE    A       A 2012-12-22   22     12

# %%
a=pd.DataFrame(file)

# %%
a[(a['Oral']=='A')&(a['Written']=='A')]
# Out:
#     Rollno                   Name Oral Written        DOB  day  month
# 1        2       AVANI AMOL KADAM    A       A 2012-01-17   17      1
# 6        7     IRA SHARAD KATWATE    A       A 2012-12-22   22     12
# 8        9    KARTIKI ROHIT KADAM    A       A 2012-05-22   22      5
# 13      14    SAKSHI ASHISH PATIL    A       A 2012-09-09    9      9
# 20      21  RUDRA RAJENDRA DALAVI    A       A 2012-05-22   22      5

# %%
a[(a['Oral']=='A')|(a['Written']=='A')]
# Out:
#     Rollno                        Name Oral Written        DOB  day  month
# 0        1          AARVI VIKRAM PATIL    A      A+ 2012-12-07    7     12
# 1        2            AVANI AMOL KADAM    A       A 2012-01-17   17      1
# 2        3     AYANA AZHARUDDIN SHAIKH    A      B+ 2012-12-31   31     12
# 5        6         HERUMBI ROHIT BAJJA    A       B 2012-09-07    7      9
# 6        7          IRA SHARAD KATWATE    A       A 2012-12-22   22     12
# 7        8  KAAVYA DATTAPRASAD BIRADAR    A       B 2012-08-13   13      8
# 8        9         KARTIKI ROHIT KADAM    A       A 2012-05-22   22      5
# 11      12         NIRVI RAKESH SHINDE   B+       A 2012-08-13   13      8
# 12      13         RIDDHI SACHIN DHAGE    A      B+ 2012-05-22   22      5
# 13      14         SAKSHI ASHISH PATIL    A       A 2012-09-09    9      9
# 14      15        SEJAL SANKET SHITOLE    A      A+ 2012-12-22   22     12
# ...

# %%
a[(a['day']>7)&(a['day']<13)]
# Out:
#     Rollno                       Name Oral Written        DOB  day  month
# 9       10      KASHVI SURESH JAYBHAY   C+     ABS 2012-09-08    8      9
# 13      14        SAKSHI ASHISH PATIL    A       A 2012-09-09    9      9
# 17      18      ANISH SANKET SALUNKHE    A      B+ 2012-09-10   10      9
# 21      22  RUDRA SHIVSHANKAR RAJBHAR    A      B+ 2012-09-11   11      9
# 25      26       SHIVANSH SURAJ YADAV  ABS     ABS 2012-09-12   12      9

# %%
file=pd.read_csv('empl.csv')

# %%
ab=pd.DataFrame(file)

# %%
ab.head()
# Out:
#    SNo   Name   Age      City  Country   Salary
# 0    1    Tom  28.0   Toronto   Canada  20000.0
# 1    2    Lee  31.0   Edmonto   Canada   3900.0
# 2    3   Dave  34.0   Toronto   Canada   8000.0
# 3    4   Anik  26.0  HongKong     Asia  66672.0
# 4    5  kamal  30.0       NaN  America      NaN

# %%
ab.isnull()
# Out:
#       SNo   Name    Age   City  Country  Salary
# 0   False  False  False  False    False   False
# 1   False  False  False  False    False   False
# 2   False  False  False  False    False   False
# 3   False  False  False  False    False   False
# 4   False  False  False   True    False    True
# 5   False  False   True  False    False   False
# 6   False  False  False  False    False   False
# 7   False  False  False  False    False   False
# 8   False  False  False  False    False   False
# 9   False  False   True  False    False   False
# 10  False  False  False  False    False   False
# 11  False  False  False   True    False   False
# 12  False  False  False  False    False   False
# 13  False  False  False   True    False   False
# 14  False  False  False  False    False   False
# 15  False  False   True  False    False   False
# 16  False  False  False  False    False   False
# 17  False  False  False  False    False    True
# 18  False  False  False  False    False   False
# ...

# %%
ab.isnull().sum()
# Out:
# SNo        0
# Name       0
# Age        3
# City       3
# Country    0
# Salary     3
# dtype: int64

# %%
ab
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
ab[ab['Name'].isna()]
# Out:
# Empty DataFrame
# Columns: [SNo, Name, Age, City, Country, Salary]
# Index: []

# %%
ab[ab['City'].isna()]
# Out:
#     SNo    Name   Age City  Country   Salary
# 4     5   kamal  30.0  NaN  America      NaN
# 11   13   kamal  30.0  NaN  America  34344.0
# 13   15  Steven  43.0  NaN  America   8300.0

# %%
ab[ab['Name'].notna()]
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
x=ab.dropna(axis=0)

# %%
x
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 16   18    yami  27.0    newyork  America   8888.0
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# 19   21   soham  32.0     Angola   Africa  34534.0
# 20   22    Grig  26.0    Finland   Europe  33451.0

# %%
x.isnull().sum()
# Out:
# SNo        0
# Name       0
# Age        0
# City       0
# Country    0
# Salary     0
# dtype: int64

# %%
import pandas as pd

# %%
x[['Country']]
# Out:
#     Country
# 0    Canada
# 1    Canada
# 2    Canada
# 3      Asia
# 6   America
# 7      Asia
# 8   America
# 10     Asia
# 12     Asia
# 14     Asia
# 16  America
# 18   Africa
# 19   Africa
# 20   Europe

# %%
# Join/concat/merge

# %%
file = pd.read_csv('empl.csv')

# %%
df1 = pd.DataFrame(file)

# %%
df1.head()
# Out:
#    SNo   Name   Age      City  Country   Salary
# 0    1    Tom  28.0   Toronto   Canada  20000.0
# 1    2    Lee  31.0   Edmonto   Canada   3900.0
# 2    3   Dave  34.0   Toronto   Canada   8000.0
# 3    4   Anik  26.0  HongKong     Asia  66672.0
# 4    5  kamal  30.0       NaN  America      NaN

# %%
file2 = pd.read_csv('countrycode.csv')

# %%
df2 = pd.DataFrame(file2)

# %%
df2.head()
# Out:
#        City   pincode
# 0   Toronto  512302.0
# 1   Edmonto  412890.0
# 2   Toronto  512302.0
# 3  HongKong  766123.0
# 4       Nan       NaN

# %%
df3 = pd.merge(df1,df2,on='City')

# %%
df3
# Out:
#     SNo    Name   Age       City  Country   Salary   pincode
# 0     1     Tom  28.0    Toronto   Canada  20000.0  512302.0
# 1     1     Tom  28.0    Toronto   Canada  20000.0  512302.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0  512302.0
# 3     3    Dave  34.0    Toronto   Canada   8000.0  512302.0
# 4     2     Lee  31.0    Edmonto   Canada   3900.0  412890.0
# 5     2     Lee  31.0    Edmonto   Canada   3900.0  412890.0
# 6    19     Lee  31.0    Edmonto   Canada      NaN  412890.0
# 7    19     Lee  31.0    Edmonto   Canada      NaN  412890.0
# 8     4    Anik  26.0   HongKong     Asia  66672.0  766123.0
# 9     4    Anik  26.0   HongKong     Asia  66672.0  766123.0
# 10    4    Anik  26.0   HongKong     Asia  66672.0  766123.0
# 11    4    Anik  26.0   HongKong     Asia  66672.0  766123.0
# 12    6    Geet   NaN   HongKong     Asia  30007.0  766123.0
# 13    6    Geet   NaN   HongKong     Asia  30007.0  766123.0
# ...

# %%
df4 = pd.merge(df1,df2,on='City',how='inner')

# %%
df4
# Out:
#     SNo    Name   Age       City  Country   Salary   pincode
# 0     1     Tom  28.0    Toronto   Canada  20000.0  512302.0
# 1     1     Tom  28.0    Toronto   Canada  20000.0  512302.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0  512302.0
# 3     3    Dave  34.0    Toronto   Canada   8000.0  512302.0
# 4     2     Lee  31.0    Edmonto   Canada   3900.0  412890.0
# 5     2     Lee  31.0    Edmonto   Canada   3900.0  412890.0
# 6    19     Lee  31.0    Edmonto   Canada      NaN  412890.0
# 7    19     Lee  31.0    Edmonto   Canada      NaN  412890.0
# 8     4    Anik  26.0   HongKong     Asia  66672.0  766123.0
# 9     4    Anik  26.0   HongKong     Asia  66672.0  766123.0
# 10    4    Anik  26.0   HongKong     Asia  66672.0  766123.0
# 11    4    Anik  26.0   HongKong     Asia  66672.0  766123.0
# 12    6    Geet   NaN   HongKong     Asia  30007.0  766123.0
# 13    6    Geet   NaN   HongKong     Asia  30007.0  766123.0
# ...

# %%
# pd.concat([df1,df2],ignore_index=True)

# %%
df3.head()
# Out:
#    SNo  Name   Age     City Country   Salary   pincode
# 0    1   Tom  28.0  Toronto  Canada  20000.0  512302.0
# 1    1   Tom  28.0  Toronto  Canada  20000.0  512302.0
# 2    3  Dave  34.0  Toronto  Canada   8000.0  512302.0
# 3    3  Dave  34.0  Toronto  Canada   8000.0  512302.0
# 4    2   Lee  31.0  Edmonto  Canada   3900.0  412890.0

# %%
df3[(df3['City']=='Toronto')&(df3['Salary']>=8000)&(df3['Salary']<=20000)]
# Out:
#    SNo  Name   Age     City Country   Salary   pincode
# 0    1   Tom  28.0  Toronto  Canada  20000.0  512302.0
# 1    1   Tom  28.0  Toronto  Canada  20000.0  512302.0
# 2    3  Dave  34.0  Toronto  Canada   8000.0  512302.0
# 3    3  Dave  34.0  Toronto  Canada   8000.0  512302.0
