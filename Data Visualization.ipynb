# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
file = pd.read_csv('NSE-TATAGLOBAL11.csv')

# %%
df = pd.DataFrame(file)

# %%
df.head()
# Out:
#         Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  10/8/2018  208.00  222.25  206.85  216.00  215.15               4642146
# 1  10/5/2018  217.00  218.60  205.90  210.25  209.20               3519515
# 2  10/4/2018  223.50  227.80  216.15  217.25  218.20               1728786
# 3  10/3/2018  230.00  237.50  225.75  226.45  227.60               1708590
# 4  10/1/2018  234.55  234.60  221.05  230.30  230.90               1534749
#
#    Turnover (Lacs)
# 0         10062.83
# 1          7407.06
# 2          3815.79
# 3          3960.27
# 4          3486.05

# %%
plt.plot(df['Open'],df['Close'])

# %%
plt.plot(df['Open'],df['Close'],'--g')

# %%
plt.bar(df['Open'],df['Close'])
# Out:
# <BarContainer object of 1235 artists>

# %%
plt.hist(df['Open'])
#also can add bins
# Out:
# (array([163., 386., 381.,  24.,  47.,  48.,  44.,  83.,  37.,  22.]),
#  array([103.  , 125.47, 147.94, 170.41, 192.88, 215.35, 237.82, 260.29,
#         282.76, 305.23, 327.7 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df['Open'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e049bd0ac0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e049bda0a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e049bd0910>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e049bda640>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e049bda910>],
#  'means': []}

# %%
plt.violinplot(df['Open'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1e0481cd6d0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1e0481cd640>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1e0481cdd90>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1e048ec3190>}

# %%
plt.scatter(df['Open'],df['Close'])

# %% [markdown]
# ### seaborn

# %%
sns.stripplot(df['Open'],df['Close'])
# Out:
# <AxesSubplot:xlabel='Open', ylabel='Close'>

# %%
sns.violinplot(df['Open'])
# Out:
# <AxesSubplot:xlabel='Open'>

# %%
sns.swarmplot(x='Open',y='Close',data=df)

# %%
sns.countplot?

# %%
sns.countplot(df['Open'])
# Out:
# <AxesSubplot:xlabel='Open', ylabel='count'>

# %%
sns.catplot(x='Open',y='Close',hue='Last',data=df,kind='bar')

# %%
sns.catplot(x='Open',y='Close',hue='Last',data=df,kind='violin')
